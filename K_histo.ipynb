# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# function to read colvar
def read_colvar(file_name):
    with open(file_name) as f:
        first_line = f.readline()
    fl = first_line[10:-1]
    names = fl.split()
    df = pd.read_csv(file_name,delim_whitespace=True, names=names, comment='#')
    return df

# %%
# loading data
new_rg_forward = read_colvar('new_rg_forward/COLVAR')
new_rg_reverse = read_colvar('new_rg_reverse/COLVAR')
chen_forward = read_colvar('chen_forward/COLVAR')
chen_reverse = read_colvar('chen_reverse/COLVAR')
R5tide_forward = read_colvar('R5tide_forward/COLVAR')
R5tide_reverse = read_colvar('R5tide_reverse/COLVAR')

# %%
# messing with some weights
kt = 2.49
wts = np.exp(new_rg_forward['pbmetad.bias'].values/kt)/(np.sum(np.exp(new_rg_forward['pbmetad.bias'].values/kt)))
new_rg_forward['weights'] = wts

# %%
wts1 = np.exp(new_rg_reverse['pbmetad.bias'].values/kt)/(np.sum(np.exp(new_rg_reverse['pbmetad.bias'].values/kt)))
new_rg_reverse['weights'] = wts1

# %%
wts2 = np.exp(chen_forward['pbmetad.bias'].values/kt)/(np.sum(np.exp(chen_forward['pbmetad.bias'].values/kt)))
chen_forward['weights'] = wts2

# %%
wts3 = np.exp(chen_reverse['pbmetad.bias'].values/kt)/(np.sum(np.exp(chen_reverse['pbmetad.bias'].values/kt)))
chen_reverse['weights'] = wts3

# %%
wts4 = np.exp(R5tide_forward['pbmetad.bias'].values/kt)/(np.sum(np.exp(R5tide_forward['pbmetad.bias'].values/kt)))
R5tide_forward['weights'] = wts4

# %%
wts5 = np.exp(R5tide_reverse['pbmetad.bias'].values/kt)/(np.sum(np.exp(R5tide_reverse['pbmetad.bias'].values/kt)))
R5tide_reverse['weights'] = wts5

# %%
# plots are v customizable so you're on your own from here
#ax = new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,alpha=1,color='blue',label='CF2',title='K3.min Weighted')
#new_rg_reverse['K3.min'].plot(kind="hist",weights=new_rg_reverse['weights'],bins=30,ax=ax,alpha=1,color='red',label='CR2')
ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF',title='K3.min Weighted, Chen Forwards')
new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=1,color='purple',label='CR')
ax.legend()

# %%
ax = chen_forward['K4.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF',title='K4.min Weighted, Chen Forwards')
new_rg_forward['K4.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=1,color='purple',label='CR')
ax.legend()

# %%
ax = chen_forward['K12.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF',title='K12.min Weighted, Chen Forwards')
new_rg_forward['K12.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=1,color='purple',label='CR')
ax.legend()

# %%
ax = chen_forward['K15.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF',title='K15.min Weighted, Chen Forwards')
new_rg_forward['K15.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=1,color='purple',label='CR')
ax.legend()

# %%
#ax = new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,alpha=1,color='blue',label='CF2',title='K3.min Weighted')
ax = new_rg_reverse['K3.min'].plot(kind="hist",weights=new_rg_reverse['weights'],bins=30,alpha=1,color='red',label='CR2', title='K3.min Weighted, Chen Reverses')
#ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF')
#new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.5,color='purple',label='CR')
ax.legend()

# %%
ax = new_rg_reverse['K4.min'].plot(kind="hist",weights=new_rg_reverse['weights'],bins=30,alpha=1,color='red',label='CR2', title='K4.min Weighted, Chen Reverses')
#ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF')
#new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

chen_reverse['K4.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.5,color='purple',label='CR')
ax.legend()

# %%
ax = new_rg_reverse['K12.min'].plot(kind="hist",weights=new_rg_reverse['weights'],bins=30,alpha=1,color='red',label='CR2', title='K12.min Weighted, Chen Reverses')
#ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF')
#new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

chen_reverse['K12.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.5,color='purple',label='CR')
ax.legend()

# %%
ax = new_rg_reverse['K15.min'].plot(kind="hist",weights=new_rg_reverse['weights'],bins=30,alpha=1,color='red',label='CR2', title='K15.min Weighted, Chen Reverses')
#ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=1,color='orange',label='CF')
#new_rg_forward['K3.min'].plot(kind="hist",weights=new_rg_forward['weights'],bins=30,ax=ax,alpha=0.5,color='blue',label='CF2')

chen_reverse['K15.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.5,color='purple',label='CR')
ax.legend()

# %%
ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=0.6,color='red',label='CF')
#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='blue',label='CR')
R5tide_forward['K3.min'].plot(kind="hist",weights=R5tide_forward['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='R5F')
R5tide_reverse['K3.min'].plot(kind="hist",weights=R5tide_reverse['weights'],bins=30,ax=ax,alpha=0.4,color='green',label='R5R')

ax.legend()

# %%
ax = chen_forward['K3.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=0.6,color='red',label='CF', title='K3.min Weighted')
#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='blue',label='CR')
R5tide_forward['K3.min'].plot(kind="hist",weights=R5tide_forward['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='R5F')
R5tide_reverse['K3.min'].plot(kind="hist",weights=R5tide_reverse['weights'],bins=30,ax=ax,alpha=0.4,color='green',label='R5R')

ax.legend()

# %%
ax = chen_forward['K4.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=0.6,color='red',label='CF', title='K4.min Weighted')
#chen_reverse['K4.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='blue',label='CR')
R5tide_forward['K4.min'].plot(kind="hist",weights=R5tide_forward['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='R5F')
R5tide_reverse['K4.min'].plot(kind="hist",weights=R5tide_reverse['weights'],bins=30,ax=ax,alpha=0.4,color='green',label='R5R')

ax.legend()

# %%
ax = chen_forward['K12.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=0.6,color='red',label='CF', title='K12.min Weighted')
#chen_reverse['K12.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='blue',label='CR')
R5tide_forward['K12.min'].plot(kind="hist",weights=R5tide_forward['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='R5F')
R5tide_reverse['K12.min'].plot(kind="hist",weights=R5tide_reverse['weights'],bins=30,ax=ax,alpha=0.4,color='green',label='R5R')

ax.legend()

# %%
ax = chen_forward['K15.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,alpha=0.6,color='red',label='CF', title='K15.min Weighted')
#chen_reverse['K15.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='blue',label='CR')
R5tide_forward['K15.min'].plot(kind="hist",weights=R5tide_forward['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='R5F')
R5tide_reverse['K15.min'].plot(kind="hist",weights=R5tide_reverse['weights'],bins=30,ax=ax,alpha=0.4,color='green',label='R5R')

ax.legend()

# %%
ax = analog_forward['K4.min'].plot(kind="hist",weights=analog_forward['weights'],bins=30,alpha=1,color='blue',label='AF',title='K4.min Weighted')
#analog_reverse['K3.min'].plot(kind="hist",weights=analog_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='red',label='AR')
chen_forward['K4.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,ax=ax,alpha=0.6,color='red',label='AR')
#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='red',label='AR')
R5tide['K4.min'].plot(kind="hist",weights=R5tide['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='AR')
ax.legend()
# Out:
# <AxesSubplot:title={'center':'K4.min Weighted'}, ylabel='Frequency'>

# %%
ax = analog_forward['K12.min'].plot(kind="hist",weights=analog_forward['weights'],bins=30,alpha=1,color='blue',label='AF', title='K12.min Weighted')
#analog_reverse['K3.min'].plot(kind="hist",weights=analog_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='red',label='AR')
chen_forward['K12.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,ax=ax,alpha=0.6,color='red',label='CF')
#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='red',label='AR')
R5tide['K12.min'].plot(kind="hist",weights=R5tide['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='AR')
ax.legend()
# Out:
# <AxesSubplot:title={'center':'K12.min Weighted'}, ylabel='Frequency'>

# %%
ax = analog_forward['K15.min'].plot(kind="hist",weights=analog_forward['weights'],bins=30,alpha=1,color='blue',label='AF',title='K15.min Weighted')
#analog_reverse['K3.min'].plot(kind="hist",weights=analog_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='red',label='AR')
chen_forward['K15.min'].plot(kind="hist",weights=chen_forward['weights'],bins=30,ax=ax,alpha=0.6,color='red',label='CF')
#chen_reverse['K3.min'].plot(kind="hist",weights=chen_reverse['weights'],bins=30,ax=ax,alpha=0.8,color='red',label='CR')
R5tide['K15.min'].plot(kind="hist",weights=R5tide['weights'],bins=30,ax=ax,alpha=0.4,color='black',label='R5tide')
ax.legend()
